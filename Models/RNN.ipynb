# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### Importing Dataset from Yahoo Finance
#
# **Common Tickers include: ['TSLA','FB','AMZN','GOOG','TWTR']**

# %%
import yfinance as yf
stock_symbol = 'TWTR'
data = yf.download(tickers=stock_symbol,period='2y',interval='1d')
data = data.reset_index()
data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date       Open       High        Low      Close  Adj Close  \
# 500 2022-05-24  36.939999  37.200001  35.400002  35.759998  35.759998
# 501 2022-05-25  36.060001  37.369999  36.020000  37.160000  37.160000
# 502 2022-05-26  38.520000  39.590000  38.230000  39.520000  39.520000
# 503 2022-05-27  39.570000  40.770000  39.480000  40.169998  40.169998
# 504 2022-05-31  40.070000  40.349998  39.419998  39.599998  39.599998
#
#        Volume
# 500  22663000
# 501  23262800
# 502  22968400
# 503  16768800
# 504  10681196

# %% [markdown]
# #### Visualizing the Real Stock Trend

# %%
plt.figure(figsize=(14,5))
plt.plot(data['Close'],color='black',label='true trend')
plt.title('%s Stock Prices'%stock_symbol)
plt.xlabel('Time')
plt.ylabel('%s Stock Prices'%stock_symbol)
plt.legend()
plt.show()

# %% [markdown]
# #### Marking a training timeframe of 60 days

# %%
test_size = 60
data_train = data[:-test_size]
data_test = data[-test_size:]
data.shape,data_train.shape,data_test.shape
# Out:
# ((505, 7), (445, 7), (60, 7))

# %% [markdown]
# #### Preparing the training data

# %%
training_data = data_train.drop(['Date','Adj Close'],axis=1)
training_data.head()
# Out:
#         Open       High        Low      Close    Volume
# 0  31.059999  32.099998  30.840000  31.889999  14583600
# 1  32.189999  32.419998  31.610001  32.259998  15318400
# 2  32.610001  35.040001  32.439999  34.880001  28396300
# 3  34.500000  34.939999  33.340000  33.720001  20265100
# 4  34.470001  35.970001  34.470001  34.869999  23211500

# %%
scaler = MinMaxScaler()
training_data = scaler.fit_transform(training_data)
training_data[0]
# Out:
# array([0.05115344, 0.0447673 , 0.05457968, 0.05846028, 0.10304867])

# %%
# Preparing the training set
x_train = []
y_train = []

for i in range(test_size, training_data.shape[0]):
    x_train.append(training_data[i-test_size:i])
    y_train.append(training_data[i,3])
# last 60 days will be the training set - X
# 61st day is the target value - Y

x_train = np.array(x_train)
y_train = np.array(y_train)

x_train.shape,y_train.shape
# Out:
# ((385, 60, 5), (385,))

# %% [markdown]
# #### Preparaing testing data

# %%
past_test_days = data_train.tail(test_size)
df = pd.concat([past_test_days,data_test])
df = df.drop(['Date','Adj Close'],axis='columns')
df.shape, df.head()
# Out:
# ((120, 5),
#            Open       High        Low      Close    Volume
#  385  44.599998  46.200001  44.340000  45.720001  18408200
#  386  47.209999  48.220001  46.410000  46.459999  26145200
#  387  46.599998  46.599998  44.970001  45.560001  14060600
#  388  45.549999  45.900002  43.779999  44.599998  11710300
#  389  44.040001  44.689999  43.700001  44.349998  11205400)

# %%
df = scaler.transform(df)
df[0]
# Out:
# array([0.32276827, 0.32161793, 0.33688832, 0.34314538, 0.13913199])

# %%
x_test = []
y_test = []

for i in range(test_size,df.shape[0]):
    x_test.append(df[i-test_size:i])
    y_test.append(df[i,3])

x_test, y_test = np.array(x_test),np.array(y_test)
x_test.shape, y_test.shape
# Out:
# ((60, 60, 5), (60,))

# %% [markdown]
# #### Defining the Scaling Label

# %%
# below is the scaling label, which will help inverse the transformation back to it's original values 
data_close = data.Close
data_close = data_close.values.reshape(-1, 1)
scaler_close = MinMaxScaler()
data_close_scaled = scaler_close.fit_transform(data_close)

# %%
y_test = y_test.reshape(-1,1)
y_test = scaler_close.inverse_transform(y_test)

# %% [markdown]
# #### RNN - Recurrent Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout

# %%
x_train.shape[1],x_train.shape[2]
# Out:
# (60, 5)

# %%
model = Sequential()

# Input layer
model.add(SimpleRNN(units=40,activation='relu',return_sequences=True, 
        input_shape=(x_train.shape[1],x_train.shape[2])))
model.add(Dropout(0.2))

# 2nd layer (Hidden)
model.add(SimpleRNN(units=60,activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(units=1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 40)            1840
#
#  dropout (Dropout)           (None, 60, 40)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60)                6060
#
#  dropout_1 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 7,961
# Trainable params: 7,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['accuracy'])

# %%
def forecast():
    model.fit(x_train,y_train,epochs=300,batch_size=64)
    y_pred = model.predict(x_test)
    y_pred = y_pred.reshape(-1,1)
    y_pred = scaler_close.inverse_transform(y_pred)
    return y_pred

# %%
def first_forecast():
    history = model.fit(x_train,y_train,epochs=300,batch_size=64)
    y_pred = model.predict(x_test)
    y_pred = y_pred.reshape(-1,1)
    y_pred = scaler_close.inverse_transform(y_pred)
    return history,y_pred

# %%
result_forecast = []
simulation = 1
print("Simulation 1")
history,first_result = first_forecast()
result_forecast.append(first_result)
for i in range(1,simulation):
    print("Simulation %d"%(i+1))
    result_forecast.append(forecast())
# Out:
# Simulation 1
# Epoch 1/300
# 7/7 [==============================] - 2s 18ms/step - loss: 0.5887 - accuracy: 0.0000e+00
# Epoch 2/300
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1742 - accuracy: 0.0000e+00
# Epoch 3/300
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0416 - accuracy: 0.0026
# Epoch 4/300
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0401 - accuracy: 0.0026
# Epoch 5/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0268 - accuracy: 0.0026
# Epoch 6/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0256 - accuracy: 0.0026
# Epoch 7/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0230 - accuracy: 0.0026
# Epoch 8/300
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0196 - accuracy: 0.0026
# Epoch 9/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0216 - accuracy: 0.0026
# Epoch 10/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0181 - accuracy: 0.0026
# Epoch 11/300
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0172 - accuracy: 0.0026
# Epoch 12/300
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0170 - accuracy: 0.0026
# Epoch 13/300
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0184 - accuracy: 0.0026
# Epoch 14/300
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0160 - accuracy: 0.0026
# Epoch 15/300
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0151 - accuracy: 0.0026
# Epoch 16/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0134 - accuracy: 0.0026
# Epoch 17/300
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 0.0026
# Epoch 18/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0128 - accuracy: 0.0026
# Epoch 19/300
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0155 - accuracy: 0.0026
# Epoch 20/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0148 - accuracy: 0.0026
# Epoch 21/300
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0138 - accuracy: 0.0026
# Epoch 22/300
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0148 - accuracy: 0.0026
# Epoch 23/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0154 - accuracy: 0.0026
# Epoch 24/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0116 - accuracy: 0.0026
# Epoch 25/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0140 - accuracy: 0.0026
# Epoch 26/300
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0124 - accuracy: 0.0000e+00
# Epoch 27/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0116 - accuracy: 0.0026
# Epoch 28/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0107 - accuracy: 0.0026
# Epoch 29/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0145 - accuracy: 0.0026
# Epoch 30/300
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0124 - accuracy: 0.0026
# Epoch 31/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0123 - accuracy: 0.0026
# Epoch 32/300
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0130 - accuracy: 0.0026
# Epoch 33/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0088 - accuracy: 0.0026
# Epoch 34/300
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0111 - accuracy: 0.0026
# Epoch 35/300
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0110 - accuracy: 0.0026
# Epoch 36/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0104 - accuracy: 0.0026
# Epoch 37/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0106 - accuracy: 0.0026
# Epoch 38/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0119 - accuracy: 0.0026
# Epoch 39/300
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0110 - accuracy: 0.0026
# Epoch 40/300
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0108 - accuracy: 0.0026
# Epoch 41/300
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0109 - accuracy: 0.0026
# Epoch 42/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.
300
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0047 - accuracy: 0.0026
# Epoch 278/300
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0053 - accuracy: 0.0026
# Epoch 279/300
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0043 - accuracy: 0.0026
# Epoch 280/300
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0049 - accuracy: 0.0026
# Epoch 281/300
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0043 - accuracy: 0.0026
# Epoch 282/300
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0040 - accuracy: 0.0026
# Epoch 283/300
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0040 - accuracy: 0.0026
# Epoch 284/300
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0034 - accuracy: 0.0026
# Epoch 285/300
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0041 - accuracy: 0.0026
# Epoch 286/300
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0036 - accuracy: 0.0026
# Epoch 287/300
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0070 - accuracy: 0.0026
# Epoch 288/300
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0058 - accuracy: 0.0026
# Epoch 289/300
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0054 - accuracy: 0.0026
# Epoch 290/300
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0050 - accuracy: 0.0026
# Epoch 291/300
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0048 - accuracy: 0.0026
# Epoch 292/300
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0045 - accuracy: 0.0026
# Epoch 293/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0039 - accuracy: 0.0026
# Epoch 294/300
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0041 - accuracy: 0.0026
# Epoch 295/300
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0042 - accuracy: 0.0026
# Epoch 296/300
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0041 - accuracy: 0.0026
# Epoch 297/300
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0042 - accuracy: 0.0026
# Epoch 298/300
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0036 - accuracy: 0.0026
# Epoch 299/300
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0036 - accuracy: 0.0026
# Epoch 300/300
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0038 - accuracy: 0.0026

# %% [markdown]
# #### Calculating the Accuracy using MAPE and RMSE

# %%
# MAPE - Mean Absolute Percentage Error
def calculate_accuracy(real, predict):
    real = np.array(real) + 1
    predict = np.array(predict) + 1
    percentage = 1 - np.mean(np.abs((real-predict)/real))
    return percentage * 100
mean_accuracy = []
for i in range(simulation):
    mean_accuracy.append(calculate_accuracy(y_test, result_forecast[i]))

mean_accuracy
# Out:
# [91.48808586954767]

# %%
# RMSE - Root Mean Squared Error 
def calculate_rmse(real, predict):
    real = np.array(real) + 1
    predict = np.array(predict) + 1
    percentage = 1 - np.sqrt(np.mean(np.square((real - predict)/real)))
    return percentage * 100
mean_rmse = []
for i in range(simulation):
    mean_rmse.append(calculate_rmse(y_test, result_forecast[i]))

mean_rmse,np.mean(mean_rmse)
# Out:
# ([88.52530661484738], 88.52530661484738)

# %% [markdown]
# #### Visualization

# %%
plt.figure(figsize=(14,5))
for i in range(simulation):
    plt.plot(result_forecast[i],label='forecast %d'%(i+1))
plt.plot(y_test,color='black',label='true trend')
plt.title('Mean Accuracy: %.4f'%np.mean(mean_accuracy))
plt.xlabel('Time')
plt.ylabel('%s Stock Prices'%stock_symbol)
plt.legend()
plt.show()

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.title('Simple RNN Model, Accuracy vs Epoch')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Simple RNN Model, Loss vs Epoch')
plt.show()

# %% [markdown]
# #### Predicting future trend

# %%
present_test_set = data_test
present_test_set = present_test_set.drop(['Date','Adj Close'],axis=1)

#scale the data
present_input = scaler.transform(present_test_set)

# preparing the arrays according to the test_size
present_test = []
present_test.append(present_input)

for i in range(1,test_size):
    a = [0,0,0,0,0]
    ar = []
    for j in range(0,test_size):
        ar.append(a)
    present_test.append(ar)

present_test = np.array(present_test)

y = model.predict(present_test)
predicted_value = y.reshape(-1,1)
predicted_value = scaler_close.inverse_transform(predicted_value)
print("Next Day's Predicted Closing Index = %f"%predicted_value[0])
# Out:
# Next Day's Predicted Closing Index = 37.670197

# %% [markdown]
# ### Final Analysis
#
# >**Dataset:**
# >* GOOG
# >* 2y
# >
# >**Training Timestamp:**
# >* 60 days
# >
# >**Model:**
# >* 3 layers - (1 Input + 1 Hidden + 1 Output)
# >* RNN layers - activation = relu
# >* RNN layers - units = 40,60
# >* RNN layers - dropout = 0.2,0.2
# >* Dense layer - units = 1
# >
# >**Compile:**
# >* optimizer = adam
# >
# >**Training:**
# >* epochs: 300
# >* batch_size = 64
# >
# >**Mean Accuracy:**
# >* MAPE - 91.11%
# >* RMSE - 86.01%
#
# **Predicted Closing Index for 29th March: 2713.892578**
